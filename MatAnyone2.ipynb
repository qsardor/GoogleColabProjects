# %% [markdown]
# <a href="https://colab.research.google.com/github/qsardor/GoogleColabProjects/blob/main/MatAnyone2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🎬 **MatAnyone2** { display-mode: "form" }
# @markdown Run this cell to set up the official repo, apply patches, and launch the Gradio UI.
# @markdown <br> *Credits: Q.SARDOR | Source: [Github](https://github.com/pq-yang/MatAnyone2)*

import os
from IPython.display import clear_output, display, HTML

display(HTML("<h3 style='color: #FF9800;'>🚀 Initializing Setup from GitHub...</h3>"))
display(HTML("<i>Downloading repository and installing dependencies. Hang tight! ☕</i>"))

# Clone the official GitHub repo silently
# !git clone https://github.com/pq-yang/MatAnyone2.git &> /dev/null

# Install requirements and apply the huggingface_hub downgrade patch silently
# !pip install -q -r /content/MatAnyone2/hugging_face/requirements.txt
# !pip install -q "huggingface_hub<0.26.0"

# Force Gradio to generate a public shareable link
# !sed -i 's/\.launch(.*)/\.launch(share=True, debug=True)/' /content/MatAnyone2/hugging_face/app.py

clear_output()
display(HTML("<h3 style='color: #4CAF50;'>✅ Environment Ready!</h3>"))
display(HTML("<p><b>⏳ Booting up MatAnyone2. Click the public 'gradio.live' URL when it appears below...</b></p>"))

# Jump into the working directory and launch the app
# %cd /content/MatAnyone2/hugging_face
# !python app.py
