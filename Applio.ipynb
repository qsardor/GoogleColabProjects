# %% [markdown]
# <a href="https://colab.research.google.com/github/qsardor/GoogleColabProjects/blob/main/Applio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🚀 Applio Streamlined Setup and Launch (One-Click)
# @markdown **Please select your preferred language.** / **Пожалуйста, выберите предпочитаемый язык.** / **Iltimos, o'zingizga qulay tilni tanlang.**
LANGUAGE = 'English' # @param ['English', 'Russian', 'Uzbek']

# @markdown
# @markdown ---
# @markdown **Credits:** Code optimized by **[QSARDOR](https://github.com/qsardor/)**. Find more Google Colab Projects: [https://github.com/qsardor/GoogleColabProjects/](https://github.com/qsardor/GoogleColabProjects/)
# @markdown ---

# --- LANGUAGE CONFIGURATION ---
MESSAGES = {
    'English': {
        'MARKDOWN_DESC': "**Run this cell once to install all dependencies and launch the Applio web interface.**",
        'MARKDOWN_URL': "When the installation is complete, a public URL link will appear in the output, allowing you to access the web UI.",
        'GPU_NOT_FOUND': "❌ GPU not detected!",
        'GPU_INSTRUCT_1': "Please ensure your Colab runtime type is set to **GPU** (e.g., T4, V100).",
        'GPU_INSTRUCT_2': "Go to **Runtime** ➡️ **Change runtime type** ➡️ Select **GPU** as the Hardware accelerator, then run this cell again! ⚙️",
        'GPU_STOP': "🛑 Stopping now. Please enable GPU! ✨",
        'GPU_NAME_UNKNOWN': "✅ GPU found, but could not determine model name.",
        'REBOOT_WARNING_1': "⚠️ Oops! It looks like you have an existing Applio installation from a previous session.",
        'REBOOT_WARNING_2': "To ensure a smooth experience, please clear the environment first. Head to **Runtime** ➡️ **Disconnect and delete runtime**, and then run this cell again! 🔄",
        'REBOOT_STOP': "🛑 Stopping for now. Come back when the environment is fresh! ✨",
        'CLONE_START': "⏳ Downloading the Applio project files... hold tight! 💾",
        'CLONE_SUCCESS': "🎉 Applio repository cloned successfully! Ready for installation.",
        'CLONE_ERROR': "Error: 'app' directory not found. Please check git clone.",
        'INSTALL_START': "🛠️ Now installing all the necessary tools and dependencies. This might take a couple of minutes! ☕",
        'INSTALL_SUCCESS': "🥳 Great news! Installation is complete and everything looks perfect! ✨",
        'LAUNCH_START': "🚀 Launching Applio web interface... Look for the public URL below!",
        'GPU_FOUND': "✅ GPU found! Using: {gpu_name}",
    },
    'Russian': {
        'MARKDOWN_DESC': "**Запустите эту ячейку один раз, чтобы установить все зависимости и запустить веб-интерфейс Applio.**",
        'MARKDOWN_URL': "Когда установка завершится, в выводе появится общедоступная ссылка (URL) для доступа к веб-интерфейсу.",
        'GPU_NOT_FOUND': "❌ GPU не обнаружен!",
        'GPU_INSTRUCT_1': "Пожалуйста, убедитесь, что тип среды выполнения Colab установлен на **GPU** (например, T4, V100).",
        'GPU_INSTRUCT_2': "Перейдите в **Среда выполнения** ➡️ **Сменить тип среды выполнения** ➡️ Выберите **GPU** в качестве аппаратного ускорителя, затем запустите эту ячейку снова! ⚙️",
        'GPU_STOP': "🛑 Останавливаемся. Пожалуйста, включите GPU! ✨",
        'GPU_NAME_UNKNOWN': "✅ GPU обнаружен, но не удалось определить название модели.",
        'REBOOT_WARNING_1': "⚠️ Ой! Похоже, у вас есть существующая установка Applio с предыдущей сессии.",
        'REBOOT_WARNING_2': "Для бесперебойной работы, пожалуйста, сначала очистите среду. Перейдите в **Среда выполнения** ➡️ **Отключить и удалить среду выполнения**, а затем запустите эту ячейку снова! 🔄",
        'REBOOT_STOP': "🛑 Останавливаемся на этом. Вернитесь, когда среда будет чистой! ✨",
        'CLONE_START': "⏳ Скачиваем файлы проекта Applio... подождите! 💾",
        'CLONE_SUCCESS': "🎉 Репозиторий Applio успешно клонирован! Готовимся к установке.",
        'CLONE_ERROR': "Ошибка: Каталог 'app' не найден. Пожалуйста, проверьте git clone.",
        'INSTALL_START': "🛠️ Устанавливаем все необходимые инструменты и зависимости. Это может занять пару минут! ☕",
        'INSTALL_SUCCESS': "🥳 Отличные новости! Установка завершена, и все выглядит идеально! ✨",
        'LAUNCH_START': "🚀 Запускаем веб-интерфейс Applio... Ищите публичную ссылку ниже!",
        'GPU_FOUND': "✅ Обнаружен GPU! Используется: {gpu_name}",
    },
    'Uzbek': {
        'MARKDOWN_DESC': "**Barcha bog'liqliklarni o'rnatish va Applio veb-interfeysini ishga tushirish uchun ushbu katakchani bir marta ishga tushiring.**",
        'MARKDOWN_URL': "O'rnatish tugallangach, veb-interfeysga kirish uchun chiqishda ommaviy URL havolasi paydo bo'ladi.",
        'GPU_NOT_FOUND': "❌ GPU aniqlanmadi!",
        'GPU_INSTRUCT_1': "Iltimos, Colab ishga tushirish turi **GPU** (masalan, T4, V100) ga o'rnatilganligiga ishonch hosil qiling.",
        'GPU_INSTRUCT_2': "**Runtime** ➡️ **Change runtime type** ➡️ **GPU** ni apparat tezlatkich sifatida tanlang, keyin ushbu katakchani yana ishga tushiring! ⚙️",
        'GPU_STOP': "🛑 Hozir to'xtaymiz. Iltimos, GPU ni yoqing! ✨",
        'GPU_NAME_UNKNOWN': "✅ GPU topildi, lekin model nomini aniqlab bo'lmadi.",
        'REBOOT_WARNING_1': "⚠️ Afsuski! Oldingi seansdan qolgan Applio o'rnatilganligi ko'rinadi.",
        'REBOOT_WARNING_2': "Muammosiz tajriba uchun, iltimos, avval muhitni tozalang. **Runtime** ➡️ **Disconnect and delete runtime** ga o'ting va keyin ushbu katakchani yana ishga tushiring! 🔄",
        'REBOOT_STOP': "🛑 Hozircha to'xtaymiz. Muhit toza bo'lganda qaytib keling! ✨",
        'CLONE_START': "⏳ Applio loyiha fayllari yuklanmoqda... sabr qiling! 💾",
        'CLONE_SUCCESS': "🎉 Applio repozitoriysi muvaffaqiyatli klonlandi! O'rnatishga tayyor.",
        'CLONE_ERROR': "Xato: 'app' katalogi topilmadi. Iltimos, git klonini tekshiring.",
        'INSTALL_START': "🛠️ Hozir barcha kerakli vositalar va bog'liqliklar o'rnatilmoqda. Bu bir necha daqiqa vaqt olishi mumkin! ☕",
        'INSTALL_SUCCESS': "🥳 Ajoyib yangilik! O'rnatish tugallandi va hamma narsa mukammal ko'rinadi! ✨",
        'LAUNCH_START': "🚀 Applio veb-interfeysi ishga tushirilmoqda... Ommaviy URL havolasini quyida qidiring!",
        'GPU_FOUND': "✅ GPU topildi! Foydalanilmoqda: {gpu_name}",
    }
}

def get_msg(key, **kwargs):
    """Retrieves a message based on the selected language and formats it."""
    # Fallback logic to ensure we always get a message, even if keys are missing
    lang_key = LANGUAGE if LANGUAGE in MESSAGES else 'English'
    message = MESSAGES.get(lang_key, MESSAGES['English']).get(key, MESSAGES['English'].get(key, f"MISSING MESSAGE: {key}"))
    return message.format(**kwargs)

import os
from IPython.display import clear_output, display, HTML

# 0. Check GPU Status
gpu_check = !nvidia-smi -L 2>&1

# Check for common error messages when GPU is not active
if "failed to initialize" in gpu_check[0] or "No devices found" in gpu_check[0] or "not found" in gpu_check[0]:
    print(get_msg('GPU_NOT_FOUND'))
    print(get_msg('GPU_INSTRUCT_1'))
    print(get_msg('GPU_INSTRUCT_2'))
    print("\n" + get_msg('GPU_STOP'))
    quit()
else:
    # GPU detected, extract and print name (assuming format "GPU 0: [Name] (UUID: ...)")
    try:
        gpu_name = gpu_check[0].split(':')[-2].split('(')[0].strip()
        print(get_msg('GPU_FOUND', gpu_name=gpu_name))
    except IndexError:
        print(get_msg('GPU_NAME_UNKNOWN'))

# 1. Check for a persistent previous installation (e.g., session reboot)
if os.path.isdir("app") and os.path.exists("app/app.py"):
    print("\n" + get_msg('REBOOT_WARNING_1'))
    print(get_msg('REBOOT_WARNING_2'))
    print("\n" + get_msg('REBOOT_STOP'))
    # Halt script execution to prevent re-installing into an existing environment
    quit()

# 2. Clone the repository and change directory
if not os.path.exists("app"):
    print("\n" + get_msg('CLONE_START'))
    # Use -q (quiet) for a cleaner log
    # !git clone -q https://github.com/harry2141985/Applio.git app
    # Clean up output from cloning before moving on
    clear_output(wait=True)
    print(get_msg('CLONE_SUCCESS'))

# Change directory
try:
    os.chdir("app")
except FileNotFoundError:
    print(get_msg('CLONE_ERROR'))
    quit() # Halt if we can't enter the directory

# 3. Install dependencies
print("\n" + get_msg('INSTALL_START'))

# Install PyTorch with a specific CUDA version (12.1 is often more reliable than 12.8 index in Colab)
# !pip install --quiet torch torchaudio torchvision --index-url https://download.pytorch.org/whl/cu121
# Install requirements
# !pip install --quiet -r requirements.txt
# Install portaudio dependency needed for some audio operations
# !apt-get install -y portaudio19-dev > /dev/null 2>&1

# --- CLEANUP STEP ---
# This command clears all the preceding installation output (the "junk")
clear_output(wait=True)

print(get_msg('INSTALL_SUCCESS'))
print("---")

# 4. Launch Applio
print(get_msg('LAUNCH_START'))
# Applio uses Gradio. Gradio automatically detects the Colab environment and provides a public share URL (or a native tunnel).
# The output cell should display the public URL link when ready.
# !python app.py
